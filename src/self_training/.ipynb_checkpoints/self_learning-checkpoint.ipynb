# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from torch.optim import Adam
from torch.utils.data import SequentialSampler
import tensorflow_datasets as tfds
import os
import sys
import subprocess

subprocess.check_call([sys.executable, "-m", "pip", "install", "milankalkenings==0.1.33"])

os.environ['KMP_DUPLICATE_LIB_OK']='True'

from milankalkenings import *


################################################################################################################
# code provided by ujjwal to download the data set


class CitrusLeaves(object):
    def __init__(self):
        self.ds = tfds.builder('citrus_leaves')
        self.ds.download_and_prepare()
        # In the following line we say that first 100 images of the training set are used as labeled dataset.
        self.ds_labeled = self.ds.as_dataset(split='train[:100]', shuffle_files=True)  # 100
        # In the following line, next 51 images are used as unlabeled set.
        self.ds_unlabeled = self.ds.as_dataset(split='train[100:151]', shuffle_files=False)  # 151
        # The remaining dataset is used for testing
        self.ds_test = self.ds.as_dataset(split='train[151:]', shuffle_files=False)

    @staticmethod
    def _map_fn(ds):
        # In this function we normalize the image in the range [-1.0, 1.0]
        image = ds['image']
        label = ds['label']
        image = tf.cast(image, tf.float32)
        image = tf.image.resize(image, size=(128, 128))
        image = tf.divide(image, 255.0)
        image = tf.multiply(image, 2.0)
        image = tf.subtract(image, 1.0)
        return image, label

    def create_train_labeled_dataset(self):
        # This gives us a dictionary indexed by an integer from 0 to number of images.
        # For each key, the value is a tuple (image, label)
        ds = self.ds_labeled.map(lambda x: self._map_fn(x))
        ds = ds.batch(1)
        data_dict = dict()
        for i, (image, label) in enumerate(ds):
            data_dict[i] = (image, label)
        return data_dict

    def create_train_unlabeled_dataset(self):
        # This gives us a dictionary indexed by an integer from 0 to number of images.
        # For each key, the value is a tuple (image, label)
        ds = self.ds_unlabeled.map(lambda x: self._map_fn(x))
        ds = ds.batch(1)
        data_dict = dict()
        for i, (image, label) in enumerate(ds):
            data_dict[i] = (image, label)
        return data_dict

    def create_test_dataset(self):
        # This gives us a dictionary indexed by an integer from 0 to number of images.
        # For each key, the value is a tuple (image, label)
        ds = self.ds_test.map(lambda x: self._map_fn(x))
        ds = ds.batch(1)
        data_dict = dict()
        for i, (image, label) in enumerate(ds):
            data_dict[i] = (image, label)
        return data_dict
################################################################################################################


def to_torch(data_dict):
    imgs = []
    labels = []
    for data_point in data_dict.values():
        imgs.append(data_point[0].numpy())
        labels.append(data_point[1].numpy())
    imgs_torch = torch.permute(torch.squeeze(torch.tensor(np.array(imgs))), [0, 3, 1, 2])
    labels_torch = torch.squeeze(torch.tensor(np.array(labels)))
    return imgs_torch, labels_torch


def create_train_loaders(train_labeled_imgs: torch.Tensor,
                         train_labeled_labels: torch.Tensor,
                         train_unlabeled_imgs: torch.Tensor,
                         batch_size: int):
    train_labeled_dataset = StandardDataset(x=train_labeled_imgs, y=train_labeled_labels)
    train_unlabeled_dataset = StandardDataset(x=train_unlabeled_imgs, y=torch.zeros(size=[len(train_unlabeled_imgs)],
                                                                                    dtype=torch.long))
    loader_train_labeled = DataLoader(dataset=train_labeled_dataset, batch_size=batch_size)
    loader_train_unlabeled = DataLoader(dataset=train_unlabeled_dataset,
                                        batch_size=batch_size,
                                        sampler=SequentialSampler(data_source=train_unlabeled_dataset))
    return loader_train_labeled, loader_train_unlabeled


def create_loaders(train_labeled_imgs: torch.Tensor,
                   train_labeled_labels: torch.Tensor,
                   train_unlabeled_imgs: torch.Tensor,
                   val_imgs: torch.Tensor,
                   val_labels: torch.Tensor,
                   batch_size: int):
    loader_train_labeled, loader_train_unlabeled = create_train_loaders(train_labeled_imgs=train_labeled_imgs,
                                                                        train_labeled_labels=train_labeled_labels,
                                                                        train_unlabeled_imgs=train_unlabeled_imgs,
                                                                        batch_size=batch_size)
    val_dataset = StandardDataset(x=val_imgs, y=val_labels)
    loader_val = DataLoader(dataset=val_dataset,
                            batch_size=batch_size,
                            sampler=SequentialSampler(data_source=val_dataset))
    return loader_train_labeled, loader_train_unlabeled, loader_val


class Classifier(Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=2)
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.flatten = nn.Flatten()
        self.linear = nn.Linear(in_features=65536, out_features=4)

        self.ce_loss = nn.CrossEntropyLoss()  # default: mean reduction

    def forward(self, x: torch.Tensor, y: torch.Tensor):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.pool(x)

        x = self.relu(self.conv3(x))
        x = self.relu(self.conv4(x))
        x = self.pool(x)

        x = self.flatten(x)
        scores = self.linear(x)
        loss = self.ce_loss(scores, y)
        return {"scores": scores, "loss": loss}


def modules_eq(module1: Module, module2: Module):
    """
    checks if two torch modules have the same parameters.
    """
    params1 = list(module1.parameters())
    params2 = list(module2.parameters())

    if len(params1) != len(params2):
        return False

    for i in range(len(params1)):
        if not torch.all(torch.eq(params1[i], params2[i])):
            return False

    return True

# %%
device = "cuda"
batch_size = 20
n_epochs = 2000
early_stopping_max_violations = 5
lrs = [0.000055] * n_epochs
checkpoint_initial = "/content/drive/MyDrive/self_learning/monitoring/checkpoint_initial.pkl"
checkpoint_running = "/content/drive/MyDrive/self_learning/monitoring/checkpoint_running.pkl"
checkpoint_final = "/content/drive/MyDrive/self_learning/monitoring/checkpoint_final.pkl"

cl = CitrusLeaves()
train_labeled_imgs, train_labeled_labels = to_torch(cl.create_train_labeled_dataset())
train_unlabeled_imgs, _ = to_torch(cl.create_train_unlabeled_dataset())
val_imgs, val_labels = to_torch(cl.create_test_dataset())
loader_train_labeled, loader_train_unlabeled, loader_val = create_loaders(train_labeled_imgs=train_labeled_imgs,
                                                                          train_labeled_labels=train_labeled_labels,
                                                                          train_unlabeled_imgs=train_unlabeled_imgs,
                                                                          val_imgs=val_imgs,
                                                                          val_labels=val_labels,
                                                                          batch_size=batch_size)

# module_initial = Classifier()
# save_secure(module=module_initial, file=checkpoint_initial)
module_initial = load_secure(file=checkpoint_initial)


val_losses = []
estimated_labels = []
train_accs = []
val_accs = []
for iteration in range(51):
    print("labeled training data points:", len(train_labeled_imgs))
    print("unlabeled training data points:", len(train_unlabeled_imgs))
    make_reproducible()
    module_initial = load_secure(file=checkpoint_initial).to(device)
    trainer = Trainer(module=module_initial,
                      loader_train=loader_train_labeled,
                      loader_val=loader_val,
                      loader_test=loader_val,
                      optimizer_class=Adam,
                      checkpoint_running=checkpoint_running,
                      checkpoint_final=checkpoint_final,
                      device=device)
    """
    trainer.determine_initial_lr(module=module_initial, 
                                 n_iters=50, 
                                 lr_candidates=[0.001, 0.0005, 0.0001, 0.00005, 0.00001], 
                                 batch_debug=next(iter(loader_train_labeled)), 
                                 save_file="/content/drive/MyDrive/self_learning/monitoring/initial_lr")
    """

    module, _, _ = trainer.train(n_epochs=n_epochs,
                                 lrs=lrs,
                                 early_stopping_max_violations=early_stopping_max_violations, 
                                 printouts=False)
    final_loss = trainer.loss_epoch_eval(module=module, loader_eval=loader_val)
    val_losses.append(final_loss)
    train_accs.append(trainer.acc_epoch_eval(module=module, loader_eval=loader_train_labeled))
    val_accs.append(trainer.acc_epoch_eval(module=module, loader_eval=loader_val))
    print("train acc:", train_accs[-1])
    print("val acc:", val_accs[-1])

    if len(train_unlabeled_imgs) > 0:
        # estimate labels
        scores = trainer.predict_epoch_scores_eval(module=module, loader_eval=loader_train_unlabeled)
        max_obs_id = torch.div(torch.argmax(input=torch.flatten(scores)), 4, rounding_mode="trunc")
        estimated_label = torch.argmax(scores[max_obs_id])

        # move observation with inferred label to the labeled training data
        train_labeled_imgs = torch.cat([train_labeled_imgs, torch.unsqueeze(train_unlabeled_imgs[max_obs_id], dim=0)], dim=0)
        train_labeled_labels = torch.cat([train_labeled_labels, torch.unsqueeze(estimated_label, dim=0).to("cpu")], dim=0)
        train_unlabeled_imgs = torch.cat([train_unlabeled_imgs[:max_obs_id], train_unlabeled_imgs[max_obs_id+1:]], dim=0)
        loader_train_labeled, loader_train_unlabeled = create_train_loaders(train_labeled_imgs=train_labeled_imgs,
                                                                            train_labeled_labels=train_labeled_labels,
                                                                            train_unlabeled_imgs=train_unlabeled_imgs,
                                                                            batch_size=batch_size)
        estimated_labels.append(estimated_label.item())
        print("estimated new label:", estimated_label.item())
        print("\n")
# Out:
# labeled training data points: 100
# unlabeled training data points: 51
# train acc: 0.8700000047683716
# val acc: 0.5981941223144531
# estimated new label: 1
#
#
# labeled training data points: 101
# unlabeled training data points: 50
# train acc: 0.910891056060791
# val acc: 0.6252821683883667
# estimated new label: 1
#
#
# labeled training data points: 102
# unlabeled training data points: 49
# train acc: 0.9215686321258545
# val acc: 0.6252821683883667
# estimated new label: 1
#
#
# labeled training data points: 103
# unlabeled training data points: 48
# train acc: 0.9320388436317444
# val acc: 0.6117381453514099
# estimated new label: 1
#
#
# labeled training data points: 104
# unlabeled training data points: 47
# train acc: 0.9230769872665405
# val acc: 0.6297968626022339
# estimated new label: 1
#
#
# labeled training data points: 105
# unlabeled training data points: 46
# train acc: 0.8857142925262451
# val acc: 0.6365688443183899
# estimated new label: 0
#
#
# labeled training data points: 106
# unlabeled training data points: 45
# train acc: 0.9245283007621765
# val acc: 0.6343115568161011
# estimated new label: 1
#
#
# labeled training data points: 107
# unlabeled training data points: 44
# train acc: 0.9345794320106506
# val acc: 0.6185101866722107
# estimated new label: 2
#
#
# labeled training data points: 108
# unlabeled training data points: 43
# train acc: 0.9351851940155029
# val acc: 0.6117381453514099
# estimated new label: 2
#
#
# labeled training data points: 109
# unlabeled training data points: 42
# train acc: 0.9266054630279541
# val acc: 0.6275395154953003
# estimated new label: 2
#
#
# labeled training data points: 110
# unlabeled training data points: 41
# train acc: 0.9272726774215698
# val acc: 0.6207675337791443
# estimated new label: 1
#
#
# labeled training data points: 111
# unlabeled training data points: 40
# train acc: 0.8918918967247009
# val acc: 0.6207675337791443
# estimated new label: 0
#
#
# labeled training data points: 112
# unlabeled training data points: 39
# train acc: 0.9642857313156128
# val acc: 0.6275395154953003
# estimated new label: 1
#
#
# labeled training data points: 113
# unlabeled training data points: 38
# train acc: 0.9380530714988708
# val acc: 0.6185101866722107
# estimated new label: 1
#
#
# labeled training data points: 114
# unlabeled training data points: 37
# train acc: 0.9385964870452881
# val acc: 0.6139954924583435
# estimated new label: 2
#
#
# labeled training data points: 115
# unlabeled training data points: 36
# train acc: 0.9565216898918152
# val acc: 0.6207675337791443
# estimated new label: 0
#
#
# labeled training data points: 116
# unlabeled training data points: 35
# train acc: 0.8362069129943848
# val acc: 0.6139954924583435
# estimated new label: 1
#
#
# labeled training data points: 117
# unlabeled training data points: 34
# train acc: 0.8461539149284363
# val acc: 0.6207675337791443
# estimated new label: 2
#
#
# labeled training data points: 118
# unlabeled training data points: 33
# train acc: 0.8474576473236084
# val acc: 0.6162528395652771
# estimated new label: 2
#
#
# labeled training data points: 119
# unlabeled training data points: 32
# train acc: 0.8487395644187927
# val acc: 0.6117381453514099
# estimated new label: 2
#
#
# labeled training data points: 120
# unlabeled training data points: 31
# train acc: 0.8416666984558105
# val acc: 0.6004514694213867
# estimated new label: 0
#
#
# labeled training data points: 121
# unlabeled training data points: 30
# train acc: 0.6694214344024658
# val acc: 0.46275395154953003
# estimated new label: 0
#
#
# labeled training data points: 122
# unlabeled training data points: 29
# train acc: 0.8934425711631775
# val acc: 0.6004514694213867
# estimated new label: 0
#
#
# labeled training data points: 123
# unlabeled training data points: 28
# train acc: 0.9512194991111755
# val acc: 0.5981941223144531
# estimated new label: 0
#
#
# labeled training data points: 124
# unlabeled training data points: 27
# train acc: 0.9596773982048035
# val acc: 0.6094807982444763
# estimated new label: 0
#
#
# labeled training data points: 125
# unlabeled training data points: 26
# train acc: 0.9440000653266907
# val acc: 0.6049661636352539
# estimated new label: 2
#
#
# labeled training data points: 126
# unlabeled training data points: 25
# train acc: 0.9285714626312256
# val acc: 0.5959368348121643
# estimated new label: 0
#
#
# labeled training data points: 127
# unlabeled training data points: 24
# train acc: 0.8582677245140076
# val acc: 0.5665914416313171
# estimated new label: 1
#
#
# labeled training data points: 128
# unlabeled training data points: 23
# train acc: 0.84375
# val acc: 0.5665914416313171
# estimated new label: 1
#
#
# labeled training data points: 129
# unlabeled training data points: 22
# train acc: 0.8372092843055725
# val acc: 0.56207674741745
# estimated new label: 1
#
#
# labeled training data points: 130
# unlabeled training data points: 21
# train acc: 0.8384615182876587
# val acc: 0.56207674741745
# estimated new label: 1
#
#
# labeled training data points: 131
# unlabeled training data points: 20
# train acc: 0.8625954389572144
# val acc: 0.6004514694213867
# estimated new label: 0
#
#
# labeled training data points: 132
# unlabeled training data points: 19
# train acc: 0.8333333730697632
# val acc: 0.5801354646682739
# estimated new label: 0
#
#
# labeled training data points: 133
# unlabeled training data points: 18
# train acc: 0.8195489048957825
# val acc: 0.5891647934913635
# estimated new label: 1
#
#
# labeled training data points: 134
# unlabeled training data points: 17
# train acc: 0.8283581733703613
# val acc: 0.5891647934913635
# estimated new label: 0
#
#
# labeled training data points: 135
# unlabeled training data points: 16
# train acc: 0.8370370268821716
# val acc: 0.5891647934913635
# estimated new label: 1
#
#
# labeled training data points: 136
# unlabeled training data points: 15
# train acc: 0.8455882668495178
# val acc: 0.5936794877052307
# estimated new label: 1
#
#
# labeled training data points: 137
# unlabeled training data points: 14
# train acc: 0.8540145754814148
# val acc: 0.6027088165283203
# estimated new label: 0
#
#
# labeled training data points: 138
# unlabeled training data points: 13
# train acc: 0.8405797481536865
# val acc: 0.6004514694213867
# estimated new label: 0
#
#
# labeled training data points: 139
# unlabeled training data points: 12
# train acc: 0.8848921060562134
# val acc: 0.6004514694213867
# estimated new label: 1
#
#
# labeled training data points: 140
# unlabeled training data points: 11
# train acc: 0.8571428656578064
# val acc: 0.5981941223144531
# estimated new label: 1
#
#
# labeled training data points: 141
# unlabeled training data points: 10
# train acc: 0.8085106015205383
# val acc: 0.5485327243804932
# estimated new label: 0
#
#
# labeled training data points: 142
# unlabeled training data points: 9
# train acc: 0.7957746386528015
# val acc: 0.5395033955574036
# estimated new label: 0
#
#
# labeled training data points: 143
# unlabeled training data points: 8
# train acc: 0.8181818127632141
# val acc: 0.5462754368782043
# estimated new label: 0
#
#
# labeled training data points: 144
# unlabeled training data points: 7
# train acc: 0.8125
# val acc: 0.5733634233474731
# estimated new label: 0
#
#
# labeled training data points: 145
# unlabeled training data points: 6
# train acc: 0.8482758402824402
# val acc: 0.5801354646682739
# estimated new label: 3
#
#
# labeled training data points: 146
# unlabeled training data points: 5
# train acc: 0.8561643958091736
# val acc: 0.5891647934913635
# estimated new label: 3
#
#
# labeled training data points: 147
# unlabeled training data points: 4
# train acc: 0.8367346525192261
# val acc: 0.5823928117752075
# estimated new label: 0
#
#
# labeled training data points: 148
# unlabeled training data points: 3
# train acc: 0.824324369430542
# val acc: 0.5756207704544067
# estimated new label: 0
#
#
# labeled training data points: 149
# unlabeled training data points: 2
# train acc: 0.8053691387176514
# val acc: 0.5823928117752075
# estimated new label: 1
#
#
# labeled training data points: 150
# unlabeled training data points: 1
# train acc: 0.8133333325386047
# val acc: 0.5846500992774963
# estimated new label: 0

# %%
import matplotlib.pyplot as plt

plt.plot(val_accs, label="validation accuracy")
plt.title("self learning")
plt.ylabel("accuracy")
plt.xlabel("amount of estimated training labels")
plt.legend()
plt.savefig("/content/drive/MyDrive/self_learning/monitoring/accs")

# %%
plt.scatter(x=torch.arange(len(estimated_labels)), y=estimated_labels)
plt.title("estimated labels")
plt.ylabel("label")
plt.xlabel("added in iteration")
plt.yticks([0, 1, 2, 3])
plt.savefig("/content/drive/MyDrive/self_learning/monitoring/labels")

# %% [markdown]
# # Findings
# - due to the small size of the initially labeled training data (100 obs.), even adding a single semi-supervised label improves the generalization ability of the network
#
# - stabilization of the training decreases, the more semi-supervised labels are added. After about 20 iterations, the achieved validation accuracy is often even lower than the validation accuracy of the supervised (iteration 0) model.
#
# - the accuracy drops harshly in iteration 21, because a vast amount of data points were labeled with the label "1", and the model simply always predicted "1" for every input. Using class weights in the cross entropy loss could be used to reduce the risk of such a training behavior, because it would lead to the less frequent classes having more impact on the loss function value.
